# %%
import torch

# %%
Prices = torch.tensor([10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 11.0102, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663, 10.9663,
        10.9663, 10.9663, 10.9663, 10.9663], dtype=torch.float64)

# %%
arg = torch.argmax(Prices)
arg
# Out:
# tensor(14)

# %%
Prices[arg].detach().numpy()
# Out:
# array(11.0102)

# %%
set(['Unnamed: 0', 'ORDERID', 'ORDERDETAILID', 'AMOUNT', 'UNITPRICE',       'TOTALPRICE', 'ITEMID', 'ITEMCODE', 'DATE_', 'CATEGORY1', 'CATEGORY2',       'cost', 'BASEPRICE', 'GMV_1D', 'GMV_7D', 'GMV_15D', 'GMV_30D',       'AMOUNT_1D', 'TOTALPRICE_1D']) 
set(['Unnamed: 0', 'ORDERID', 'ORDERDETAILID', 'AMOUNT', 'UNITPRICE',       'TOTALPRICE', 'ITEMID', 'ITEMCODE', 'DATE_', 'CATEGORY1', 'CATEGORY2',       'cost', 'BASEPRICE'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 set(['Unnamed: 0', 'ORDERID', 'ORDERDETAILID', 'AMOUNT', 'UNITPRICE',       'TOTALPRICE', 'ITEMID', 'ITEMCODE', 'DATE_', 'CATEGORY1', 'CATEGORY2',       'cost', 'BASEPRICE', 'GMV_1D', 'GMV_7D', 'GMV_15D', 'GMV_30D',       'AMOUNT_1D', 'TOTALPRICE_1D'])
# ----> 2 - set(['Unnamed: 0', 'ORDERID', 'ORDERDETAILID', 'AMOUNT', 'UNITPRICE',       'TOTALPRICE', 'ITEMID', 'ITEMCODE', 'DATE_', 'CATEGORY1', 'CATEGORY2',       'cost', 'BASEPRICE'])
#
# TypeError: bad operand type for unary -: 'set'

# %%
{'a': 1, 'v': 2} | {'c': 4}
# Out:
# {'a': 1, 'v': 2, 'c': 4}
